# %%
# import os
os.environ["MKL_NUM_THREADS"] = "1" 
os.environ["NUMEXPR_NUM_THREADS"] = "1" 
os.environ["OMP_NUM_THREADS"] = "1"
from os import path, listdir
import numpy as np
np.random.seed(1)
import random
random.seed(1)
import pandas as pd
import timeit
import cv2
from tqdm import tqdm

import sys
sys.setrecursionlimit(10000)
from multiprocessing import Pool

from shapely.geometry.linestring import LineString
# from skimage.morphology import skeletonize_3d, square, erosion, dilation, medial_axis
# from skimage.measure import label, regionprops, approximate_polygon
from math import hypot, sin, cos, asin, acos, radians
from sklearn.neighbors import KDTree
from shapely.wkt import dumps, loads

import scipy

import utm
#pip install utm
from osgeo import gdal
gdal.UseExceptions()
from osgeo import osr
from osgeo import ogr
#conda install gdal

import ntpath
from shapely.geometry import mapping, Point, LineString

# import matplotlib.pyplot as plt
# import seaborn as sns

pred_folders = ['./wdata/test_pred']

speed_bins = np.array([15, 18.75, 20, 25, 30, 35, 45, 55, 65])

test_folders = ['/fs/scratch/PCON0003/osu10670/AOI_7_Moscow_test', '/fs/scratch/PCON0003/osu10670/AOI_8_Mumbai_test']
# test_folders = []
# for i in range(1, len(sys.argv) - 1):
#     test_folders.append(sys.argv[i])

df = pd.read_csv(path.join('./wdata', 'solution_length.csv'), header=None)
df.columns = ['ImageId', 'WKT_Pix']

# example GDAL error handler function
def gdal_error_handler(err_class, err_num, err_msg):
    errtype = {
            gdal.CE_None:'None',
            gdal.CE_Debug:'Debug',
            gdal.CE_Warning:'Warning',
            gdal.CE_Failure:'Failure',
            gdal.CE_Fatal:'Fatal'
    }
    err_msg = err_msg.replace('\n',' ')
    err_class = errtype.get(err_class, 'None')
    print('Error Number: ', (err_num))
    print('Error Type: ', (err_class))
    print('Error Message: ', (err_msg))
    
gdal.PushErrorHandler(gdal_error_handler)

# from https://github.com/CosmiQ/cresi
def get_linestring_midpoints(geom):
    '''Get midpoints of each line segment in the line.
    Also return the length of each segment, assuming cartesian coordinates'''
    coords = list(geom.coords)
    N = len(coords)
    x_mids, y_mids, dls = [], [], []
    for i in range(N-1):
        (x0, y0) = coords[i]
        (x1, y1) = coords[i+1]
        x_mids.append(np.rint(0.5 * (x0 + x1)))
        y_mids.append(np.rint(0.5 * (y0 + y1)))
        dl = scipy.spatial.distance.euclidean(coords[i], coords[i+1])
        dls. append(dl)
    return np.array(x_mids).astype(int), np.array(y_mids).astype(int), \
                np.array(dls)


def pixelToGeoCoord(xPix, yPix, inputRaster, sourceSR='', geomTransform='', targetSR=''):
    '''from spacenet geotools'''

    if targetSR =='':
        performReprojection=False
        targetSR = osr.SpatialReference()
        targetSR.ImportFromEPSG(4326)
    else:
        performReprojection=True

    if geomTransform=='':
        srcRaster = gdal.Open(inputRaster)
        geomTransform = srcRaster.GetGeoTransform()

        source_sr = osr.SpatialReference()
        source_sr.ImportFromWkt(srcRaster.GetProjectionRef())

    geom = ogr.Geometry(ogr.wkbPoint)
    xOrigin = geomTransform[0]
    yOrigin = geomTransform[3]
    pixelWidth = geomTransform[1]
    pixelHeight = geomTransform[5]

    xCoord = (xPix * pixelWidth) + xOrigin
    yCoord = (yPix * pixelHeight) + yOrigin
    geom.AddPoint(xCoord, yCoord)

    if performReprojection:
        if sourceSR=='':
            srcRaster = gdal.Open(inputRaster)
            sourceSR = osr.SpatialReference()
            sourceSR.ImportFromWkt(srcRaster.GetProjectionRef())
        coord_trans = osr.CoordinateTransformation(sourceSR, targetSR)
        geom.Transform(coord_trans)

    return (geom.GetX(), geom.GetY())


def convert_pix_lstring_to_geo(wkt_lstring, im_file, 
                               utm_zone=None, utm_letter=None, verbose=False):
    '''Convert linestring in pixel coords to geo coords
    If zone or letter changes inthe middle of line, it's all screwed up, so
    force zone and letter based on first point
    (latitude, longitude, force_zone_number=None, force_zone_letter=None)
    Or just force utm zone and letter explicitly
        '''
    shape = wkt_lstring  #shapely.wkt.loads(lstring)
    x_pixs, y_pixs = shape.coords.xy
    coords_latlon = []
    coords_utm = []
    for i,(x,y) in enumerate(zip(x_pixs, y_pixs)):
        
        targetSR = osr.SpatialReference()
        targetSR.ImportFromEPSG(4326)
        lon, lat = pixelToGeoCoord(x, y, im_file, targetSR=targetSR)

        if utm_zone and utm_letter:
            [utm_east, utm_north, _, _] = utm.from_latlon(lat, lon,
                force_zone_number=utm_zone, force_zone_letter=utm_letter)
        else:
            [utm_east, utm_north, utm_zone, utm_letter] = utm.from_latlon(lat, lon)
        
        if verbose:
            print("lat lon, utm_east, utm_north, utm_zone, utm_letter]",
                [lat, lon, utm_east, utm_north, utm_zone, utm_letter])
        coords_utm.append([utm_east, utm_north])
        coords_latlon.append([lon, lat])
    
    lstring_latlon = LineString([Point(z) for z in coords_latlon])
    lstring_utm = LineString([Point(z) for z in coords_utm])
    
    return lstring_latlon, lstring_utm, utm_zone, utm_letter

meters_to_miles = 0.000621371

###########


def get_linestring_keypoints(geom):
    coords = list(geom.coords)
    N = len(coords)
    xs, ys, dls = [], [], []
    for i in range(N-1):
        xs.append([])
        ys.append([])

        (x0, y0) = coords[i]
        (x1, y1) = coords[i+1]
        
        xs[i].append(0.5 * x0 + 0.5 * x1)
        ys[i].append(0.5 * y0 + 0.5 * y1)
        xs[i].append(0.75 * x0 + 0.25 * x1)
        ys[i].append(0.75 * y0 + 0.25 * y1)
        xs[i].append(0.25 * x0 + 0.75 * x1)
        ys[i].append(0.25 * y0 + 0.75 * y1)
        xs[i].append(0.9 * x0 + 0.1 * x1)
        ys[i].append(0.9 * y0 + 0.1 * y1)
        xs[i].append(0.1 * x0 + 0.9 * x1)
        ys[i].append(0.1 * y0 + 0.9 * y1)
        xs[i].append(0.35 * x0 + 0.65 * x1)
        ys[i].append(0.35 * y0 + 0.65 * y1)
        xs[i].append(0.65 * x0 + 0.35 * x1)
        ys[i].append(0.65 * y0 + 0.35 * y1)

        dl = scipy.spatial.distance.euclidean(coords[i], coords[i+1])
        dls. append(dl)
    return xs, ys, np.asarray(dls)



def process_file(fn):
    
    img_id = ntpath.basename(fn)[0:-4]
    img_id = img_id.replace('_PS-MS', '')
    print(img_id)
    
    im_file = fn
    
    msks = []
    for pred_folder in pred_folders:
        msk0 = cv2.imread(path.join(pred_folder, img_id + '_speed0.png'), cv2.IMREAD_UNCHANGED)
        msk1 = cv2.imread(path.join(pred_folder, img_id + '_speed1.png'), cv2.IMREAD_UNCHANGED)
        msk2 = cv2.imread(path.join(pred_folder, img_id + '_speed2.png'), cv2.IMREAD_UNCHANGED)
        msk = np.concatenate((msk0, msk1, msk2), axis=2)
        if msk.shape[0] < 1306:
            msk = cv2.resize(msk, (1300, 1300))
            msk = np.pad(msk, ((6, 6), (6, 6), (0, 0)), mode='reflect')
        msks.append(msk)
    msks = np.asarray(msks)
    msk = msks.mean(axis=0)
    msk = msk[6:1306, 6:1306].astype('uint8')
    
    vals = df[(df['ImageId'] == img_id)]['WKT_Pix'].values
    res_rows = []
    for v in vals:
        if v == 'LINESTRING EMPTY':
            return [{'ImageId': img_id, 'WKT_Pix': 'LINESTRING EMPTY', 'length_m': 0, 'travel_time_s': 0}]
        
        l = loads(v)
        
        lstring_latlon, lstring_utm, utm_zone, utm_letter = convert_pix_lstring_to_geo(l, im_file)
    
        length = lstring_utm.length
        length_miles = length * meters_to_miles
        
#         x_mids, y_mids, dls = get_linestring_midpoints(l)
        xs, ys, dls = get_linestring_keypoints(l)
        
        _sz = 4

#         speed = []
#         if x_mids.shape[0] > 0:
#             for i in range(x_mids.shape[0]):
#                 x0 = max(0, x_mids[i] - _sz)
#                 x1= min(1300, x_mids[i] + _sz)
#                 y0 = max(0, y_mids[i] - _sz)
#                 y1= min(1300, y_mids[i] + _sz)
#                 patch = msk[y0:y1, x0:x1]
#                 means = patch.mean(axis=(0, 1))
                
#                 if means.sum() == 0:
#                     speed.append(25)
#                 else:
#                     means /= means.sum()
#                     _s = (speed_bins * means).sum()
#                     if _s < 15:
#                         _s = 15
#                     if _s > 65:
#                         _s = 65
#                     speed.append(_s)
                    
        speed = []
        if len(xs) > 0:
            for i in range(len(xs)):
                seg_speeds = []
                for j in range(len(xs[i])):
                    x0 = max(0, int(xs[i][j] - _sz))
                    x1= min(1300, int(xs[i][j] + _sz))
                    y0 = max(0, int(ys[i][j] - _sz))
                    y1= min(1300, int(ys[i][j] + _sz))
                    
                    patch = msk[y0:y1, x0:x1]
                    means = patch.mean(axis=(0, 1))

                if means.sum() == 0:
                    seg_speeds.append(25)
                else:
                    means /= means.sum()
                    _s = (speed_bins * means).sum()
                    if _s < 15:
                        _s = 15
                    if _s > 65:
                        _s = 65
                    seg_speeds.append(_s)
                speed.append(np.mean(seg_speeds))
                    
        speed = np.asarray(speed)
        dls /= dls.sum()
        speed = (speed * dls).sum()
        
        if speed < 15:
            speed = 15
        if speed > 65:
            speed = 65
                        
        hours = length_miles / speed
        
        travel_time_s = np.round(3600. * hours, 3)
        
        res_rows.append({'ImageId': img_id, 'WKT_Pix': v, 'length_m': length, 'travel_time_s': travel_time_s})


    return res_rows

# %%
# if __name__ == '__main__':
t0 = timeit.default_timer()

#     out_file = sys.argv[-1]

out_file = 'solution.csv'

all_files = []
for d in test_folders:
    for f in listdir(path.join(d, 'PS-MS')):
        if '.tif' in f:
            all_files.append(path.join(d+'/PS-MS',f))

#     for fn in tqdm(all_files):
#         process_file(fn)

# %%
a = process_file(all_files[0])
# Out:
# SN5_roads_test_public_AOI_7_Moscow_chip101

# %%
# Out:
# [{'ImageId': 'SN5_roads_test_public_AOI_7_Moscow_chip101',
#   'WKT_Pix': 'LINESTRING (32 130, 33 136, 42 176, 66 254, 70 281, 91 375, 143 547, 173 672, 196 757, 215 816, 225 863, 275 1006, 287 1062, 291 1095, 293 1109)',
#   'length_m': 343.03892300344666,
#   'travel_time_s': 27.517},
#  {'ImageId': 'SN5_roads_test_public_AOI_7_Moscow_chip101',
#   'WKT_Pix': 'LINESTRING (293 1109, 318 1212, 332 1259, 334 1265)',
#   'length_m': 54.622218692518075,
#   'travel_time_s': 5.405}]

# %%
with Pool() as pool:
    results = pool.map(process_file, all_files)
# Out:
# SN5_roads_test_public_AOI_7_Moscow_chip101SN5_roads_test_public_AOI_7_Moscow_chip164SN5_roads_test_public_AOI_7_Moscow_chip171SN5_roads_test_public_AOI_7_Moscow_chip120SN5_roads_test_public_AOI_7_Moscow_chip65
#
# SN5_roads_test_public_AOI_7_Moscow_chip152SN5_roads_test_public_AOI_7_Moscow_chip138SN5_roads_test_public_AOI_7_Moscow_chip193SN5_roads_test_public_AOI_7_Moscow_chip155SN5_roads_test_public_AOI_7_Moscow_chip96SN5_roads_test_public_AOI_7_Moscow_chip178
#
#
#
#
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip197SN5_roads_test_public_AOI_7_Moscow_chip132SN5_roads_test_public_AOI_7_Moscow_chip48SN5_roads_test_public_AOI_7_Moscow_chip95SN5_roads_test_public_AOI_7_Moscow_chip137SN5_roads_test_public_AOI_7_Moscow_chip115SN5_roads_test_public_AOI_7_Moscow_chip194SN5_roads_test_public_AOI_7_Moscow_chip219SN5_roads_test_public_AOI_7_Moscow_chip209
# SN5_roads_test_public_AOI_7_Moscow_chip0SN5_roads_test_public_AOI_7_Moscow_chip121SN5_roads_test_public_AOI_7_Moscow_chip200
#
# SN5_roads_test_public_AOI_7_Moscow_chip202SN5_roads_test_public_AOI_7_Moscow_chip140
# SN5_roads_test_public_AOI_7_Moscow_chip225SN5_roads_test_public_AOI_7_Moscow_chip86SN5_roads_test_public_AOI_7_Moscow_chip75SN5_roads_test_public_AOI_7_Moscow_chip201SN5_roads_test_public_AOI_7_Moscow_chip199SN5_roads_test_public_AOI_7_Moscow_chip174
# SN5_roads_test_public_AOI_7_Moscow_chip81
# SN5_roads_test_public_AOI_7_Moscow_chip159SN5_roads_test_public_AOI_7_Moscow_chip7
# SN5_roads_test_public_AOI_7_Moscow_chip185
#
# SN5_roads_test_public_AOI_7_Moscow_chip130SN5_roads_test_public_AOI_7_Moscow_chip88SN5_roads_test_public_AOI_7_Moscow_chip205
#
# SN5_roads_test_public_AOI_7_Moscow_chip50
#
#
#
#
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip221
#
#
#
#
#
#
#
#
#
#
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip176
# SN5_roads_test_public_AOI_7_Moscow_chip85
# SN5_roads_test_public_AOI_7_Moscow_chip172
# SN5_roads_test_public_AOI_7_Moscow_chip97
# SN5_roads_test_public_AOI_7_Moscow_chip10
# SN5_roads_test_public_AOI_7_Moscow_chip173
# SN5_roads_test_public_AOI_7_Moscow_chip100
# SN5_roads_test_public_AOI_7_Moscow_chip52
# SN5_roads_test_public_AOI_7_Moscow_chip223
# SN5_roads_test_public_AOI_7_Moscow_chip157
# SN5_roads_test_public_AOI_7_Moscow_chip133
# SN5_roads_test_public_AOI_7_Moscow_chip54
# SN5_roads_test_public_AOI_7_Moscow_chip24
# SN5_roads_test_public_AOI_7_Moscow_chip124
# SN5_roads_test_public_AOI_7_Moscow_chip182
# SN5_roads_test_public_AOI_7_Moscow_chip204
# SN5_roads_test_public_AOI_7_Moscow_chip42
# SN5_roads_test_public_AOI_7_Moscow_chip106
# SN5_roads_test_public_AOI_7_Moscow_chip208
# SN5_roads_test_public_AOI_7_Moscow_chip190
# SN5_roads_test_public_AOI_7_Moscow_chip14
# SN5_roads_test_public_AOI_7_Moscow_chip32
# SN5_roads_test_public_AOI_7_Moscow_chip198SN5_roads_test_public_AOI_7_Moscow_chip168SN5_roads_test_public_AOI_7_Moscow_chip128
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip53SN5_roads_test_public_AOI_7_Moscow_chip87
# SN5_roads_test_public_AOI_7_Moscow_chip189
#
# SN5_roads_test_public_AOI_7_Moscow_chip78
# SN5_roads_test_public_AOI_7_Moscow_chip6
# SN5_roads_test_public_AOI_7_Moscow_chip112
# SN5_roads_test_public_AOI_7_Moscow_chip127SN5_roads_test_public_AOI_7_Moscow_chip179
#
# SN5_roads_test_public_AOI_7_Moscow_chip160
# SN5_roads_test_public_AOI_7_Moscow_chip135
# SN5_roads_test_public_AOI_7_Moscow_chip125
# SN5_roads_test_public_AOI_7_Moscow_chip110
# SN5_roads_test_public_AOI_7_Moscow_chip212
# SN5_roads_test_public_AOI_7_Moscow_chip105
# SN5_roads_test_public_AOI_7_Moscow_chip226SN5_roads_test_public_AOI_7_Moscow_chip103
# SN5_roads_test_public_AOI_7_Moscow_chip92
# SN5_roads_test_public_AOI_7_Moscow_chip8
#
# SN5_roads_test_public_AOI_7_Moscow_chip151
# SN5_roads_test_public_AOI_7_Moscow_chip2
# SN5_roads_test_public_AOI_7_Moscow_chip148
# SN5_roads_test_public_AOI_7_Moscow_chip11
# SN5_roads_test_public_AOI_7_Moscow_chip39
# SN5_roads_test_public_AOI_7_Moscow_chip166
# SN5_roads_test_public_AOI_7_Moscow_chip136
# SN5_roads_test_public_AOI_7_Moscow_chip210
# SN5_roads_test_public_AOI_7_Moscow_chip161
# SN5_roads_test_public_AOI_7_Moscow_chip62SN5_roads_test_public_AOI_7_Moscow_chip40
#
# SN5_roads_test_public_AOI_7_Moscow_chip126
# SN5_roads_test_public_AOI_7_Moscow_chip222SN5_roads_test_public_AOI_7_Moscow_chip19SN5_roads_test_public_AOI_7_Moscow_chip74
#
# SN5_roads_test_public_AOI_7_Moscow_chip131
#
# SN5_roads_test_public_AOI_7_Moscow_chip122
# SN5_roads_test_public_AOI_7_Moscow_chip27
# SN5_roads_test_public_AOI_7_Moscow_chip79SN5_roads_test_public_AOI_7_Moscow_chip153SN5_roads_test_public_AOI_7_Moscow_chip227
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip18
# SN5_roads_test_public_AOI_7_Moscow_chip77SN5_roads_test_public_AOI_7_Moscow_chip5
# SN5_roads_test_public_AOI_7_Moscow_chip213SN5_roads_test_public_AOI_7_Moscow_chip90
#
# SN5_roads_test_public_AOI_7_Moscow_chip163
#
# SN5_roads_test_public_AOI_7_Moscow_chip192SN5_roads_test_public_AOI_7_Moscow_chip216
#
# SN5_roads_test_public_AOI_7_Moscow_chip1SN5_roads_test_public_AOI_7_Moscow_chip187
#
# SN5_roads_test_public_AOI_7_Moscow_chip64
# SN5_roads_test_public_AOI_7_Moscow_chip144SN5_roads_test_public_AOI_7_Moscow_chip149
#
# SN5_roads_test_public_AOI_7_Moscow_chip51
# SN5_roads_test_public_AOI_7_Moscow_chip72
# SN5_roads_test_public_AOI_7_Moscow_chip67
# SN5_roads_test_public_AOI_7_Moscow_chip29SN5_roads_test_public_AOI_7_Moscow_chip186
#
# SN5_roads_test_public_AOI_7_Moscow_chip66
# SN5_roads_test_public_AOI_7_Moscow_chip9
# SN5_roads_test_public_AOI_7_Moscow_chip4
# SN5_roads_test_public_AOI_7_Moscow_chip217
# SN5_roads_test_public_AOI_7_Moscow_chip146
# SN5_roads_test_public_AOI_7_Moscow_chip63SN5_roads_test_public_AOI_7_Moscow_chip59
#
# SN5_roads_test_public_AOI_7_Moscow_chip80
# SN5_roads_test_public_AOI_7_Moscow_chip33
# SN5_roads_test_public_AOI_7_Moscow_chip15SN5_roads_test_public_AOI_7_Moscow_chip102
#
# SN5_roads_test_public_AOI_7_Moscow_chip22SN5_roads_test_public_AOI_7_Moscow_chip47
#
# SN5_roads_test_public_AOI_7_Moscow_chip89
# SN5_roads_test_public_AOI_7_Moscow_chip16
# SN5_roads_test_public_AOI_7_Moscow_chip158
# SN5_roads_test_public_AOI_7_Moscow_chip30
# SN5_roads_test_public_AOI_7_Moscow_chip69
# SN5_roads_test_public_AOI_7_Moscow_chip188
# SN5_roads_test_public_AOI_7_Moscow_chip119
# SN5_roads_test_public_AOI_7_Moscow_chip38
# SN5_roads_test_public_AOI_7_Moscow_chip147
# SN5_roads_test_public_AOI_7_Moscow_chip44
# SN5_roads_test_public_AOI_7_Moscow_chip83
# SN5_roads_test_public_AOI_7_Moscow_chip109SN5_roads_test_public_AOI_7_Moscow_chip104
#
# SN5_roads_test_public_AOI_7_Moscow_chip71SN5_roads_test_public_AOI_7_Moscow_chip181
#
# SN5_roads_test_public_AOI_7_Moscow_chip57
# SN5_roads_test_public_AOI_7_Moscow_chip98SN5_roads_test_public_AOI_7_Moscow_chip68
#
# SN5_roads_test_public_AOI_7_Moscow_chip214
# SN5_roads_test_public_AOI_7_Moscow_chip82
# SN5_roads_test_public_AOI_7_Moscow_chip183
# SN5_roads_test_public_AOI_7_Moscow_chip143
# SN5_roads_test_public_AOI_7_Moscow_chip215SN5_roads_test_public_AOI_7_Moscow_chip129
#
# SN5_roads_test_public_AOI_7_Moscow_chip91
# SN5_roads_test_public_AOI_7_Moscow_chip207
# SN5_roads_test_public_AOI_7_Moscow_chip35
# SN5_roads_test_public_AOI_7_Moscow_chip41
# SN5_roads_test_public_AOI_7_Moscow_chip26
# SN5_roads_test_public_AOI_7_Moscow_chip49
# SN5_roads_test_public_AOI_7_Moscow_chip43
# SN5_roads_test_public_AOI_7_Moscow_chip17
# SN5_roads_test_public_AOI_7_Moscow_chip13
# SN5_roads_test_public_AOI_7_Moscow_chip94SN5_roads_test_public_AOI_7_Moscow_chip99
# SN5_roads_test_public_AOI_7_Moscow_chip141
#
# SN5_roads_test_public_AOI_7_Moscow_chip45
# SN5_roads_test_public_AOI_7_Moscow_chip23
# SN5_roads_test_public_AOI_7_Moscow_chip150
# SN5_roads_test_public_AOI_7_Moscow_chip170
# SN5_roads_test_public_AOI_7_Moscow_chip139
# SN5_roads_test_public_AOI_7_Moscow_chip191
# SN5_roads_test_public_AOI_7_Moscow_chip12
# SN5_roads_test_public_AOI_7_Moscow_chip73
# SN5_roads_test_public_AOI_7_Moscow_chip206
# SN5_roads_test_public_AOI_7_Moscow_chip162SN5_roads_test_public_AOI_7_Moscow_chip203
#
# SN5_roads_test_public_AOI_8_Mumbai_chip80
# SN5_roads_test_public_AOI_8_Mumbai_chip132
# SN5_roads_test_public_AOI_8_Mumbai_chip109
# SN5_roads_test_public_AOI_7_Moscow_chip28
# SN5_roads_test_public_AOI_7_Moscow_chip224
# SN5_roads_test_public_AOI_7_Moscow_chip123
# SN5_roads_test_public_AOI_7_Moscow_chip111
# SN5_roads_test_public_AOI_7_Moscow_chip61
# SN5_roads_test_public_AOI_7_Moscow_chip195
# SN5_roads_test_public_AOI_7_Moscow_chip70
# SN5_roads_test_public_AOI_7_Moscow_chip56
# SN5_roads_test_public_AOI_8_Mumbai_chip125SN5_roads_test_public_AOI_8_Mumbai_chip71SN5_roads_test_public_AOI_8_Mumbai_chip37
#
#
# SN5_roads_test_public_AOI_8_Mumbai_chip36
# SN5_roads_test_public_AOI_7_Moscow_chip113
# SN5_roads_test_public_AOI_8_Mumbai_chip5SN5_roads_test_public_AOI_8_Mumbai_chip44
#
# SN5_roads_test_public_AOI_7_Moscow_chip20SN5_roads_test_public_AOI_8_Mumbai_chip127SN5_roads_test_public_AOI_7_Moscow_chip93
# SN5_roads_test_public_AOI_8_Mumbai_chip11
# SN5_roads_test_public_AOI_7_Moscow_chip175
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip76
# SN5_roads_test_public_AOI_8_Mumbai_chip108
# SN5_roads_test_public_AOI_7_Moscow_chip3
# SN5_roads_test_public_AOI_7_Moscow_chip55
# SN5_roads_test_public_AOI_7_Moscow_chip21
# SN5_roads_test_public_AOI_8_Mumbai_chip97SN5_roads_test_public_AOI_7_Moscow_chip114
#
# SN5_roads_test_public_AOI_7_Moscow_chip107
# SN5_roads_test_public_AOI_7_Moscow_chip108SN5_roads_test_public_AOI_8_Mumbai_chip165
# SN5_roads_test_public_AOI_7_Moscow_chip34SN5_roads_test_public_AOI_8_Mumbai_chip128
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip154
# SN5_roads_test_public_AOI_7_Moscow_chip165SN5_roads_test_public_AOI_7_Moscow_chip156
# SN5_roads_test_public_AOI_8_Mumbai_chip74
#
# SN5_roads_test_public_AOI_8_Mumbai_chip118
# SN5_roads_test_public_AOI_8_Mumbai_chip22
# SN5_roads_test_public_AOI_7_Moscow_chip220
# SN5_roads_test_public_AOI_8_Mumbai_chip31SN5_roads_test_public_AOI_8_Mumbai_chip146
#
# SN5_roads_test_public_AOI_7_Moscow_chip145
# SN5_roads_test_public_AOI_8_Mumbai_chip134SN5_roads_test_public_AOI_7_Moscow_chip117
# SN5_roads_test_public_AOI_8_Mumbai_chip98
#
# SN5_roads_test_public_AOI_7_Moscow_chip46
# SN5_roads_test_public_AOI_8_Mumbai_chip1SN5_roads_test_public_AOI_8_Mumbai_chip124SN5_roads_test_public_AOI_8_Mumbai_chip175
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip60SN5_roads_test_public_AOI_8_Mumbai_chip85
# SN5_roads_test_public_AOI_7_Moscow_chip31
#
# SN5_roads_test_public_AOI_8_Mumbai_chip67SN5_roads_test_public_AOI_8_Mumbai_chip92SN5_roads_test_public_AOI_8_Mumbai_chip99
# SN5_roads_test_public_AOI_7_Moscow_chip167
# SN5_roads_test_public_AOI_8_Mumbai_chip150
#
# SN5_roads_test_public_AOI_7_Moscow_chip142
# SN5_roads_test_public_AOI_7_Moscow_chip118
# SN5_roads_test_public_AOI_8_Mumbai_chip169SN5_roads_test_public_AOI_7_Moscow_chip36
# SN5_roads_test_public_AOI_8_Mumbai_chip116
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip218
# SN5_roads_test_public_AOI_8_Mumbai_chip141
# SN5_roads_test_public_AOI_7_Moscow_chip211SN5_roads_test_public_AOI_8_Mumbai_chip95
#
# SN5_roads_test_public_AOI_8_Mumbai_chip79SN5_roads_test_public_AOI_8_Mumbai_chip15
#
# SN5_roads_test_public_AOI_7_Moscow_chip184
# SN5_roads_test_public_AOI_8_Mumbai_chip159SN5_roads_test_public_AOI_8_Mumbai_chip114SN5_roads_test_public_AOI_8_Mumbai_chip147
#
#
# SN5_roads_test_public_AOI_8_Mumbai_chip68
# SN5_roads_test_public_AOI_8_Mumbai_chip161
# SN5_roads_test_public_AOI_8_Mumbai_chip148
# SN5_roads_test_public_AOI_8_Mumbai_chip48SN5_roads_test_public_AOI_8_Mumbai_chip55SN5_roads_test_public_AOI_7_Moscow_chip180
#
#
# SN5_roads_test_public_AOI_7_Moscow_chip116
# SN5_roads_test_public_AOI_8_Mumbai_chip57SN5_roads_test_public_AOI_8_Mumbai_chip104
#
# SN5_roads_test_public_AOI_8_Mumbai_chip50
# SN5_roads_test_public_AOI_8_Mumbai_chip110
# SN5_roads_test_public_AOI_8_Mumbai_chip164
# SN5_roads_test_public_AOI_8_Mumbai_chip87SN5_roads_test_public_AOI_8_Mumbai_chip13
#
# SN5_roads_test_public_AOI_7_Moscow_chip37
# SN5_roads_test_public_AOI_8_Mumbai_chip117
# SN5_roads_test_public_AOI_8_Mumbai_chip171
# SN5_roads_test_public_AOI_8_Mumbai_chip173SN5_roads_test_public_AOI_8_Mumbai_chip88
#
# SN5_roads_test_public_AOI_8_Mumbai_chip145
# SN5_roads_test_public_AOI_8_Mumbai_chip39
# SN5_roads_test_public_AOI_8_Mumbai_chip4
# SN5_roads_test_public_AOI_8_Mumbai_chip113
# SN5_roads_test_public_AOI_7_Moscow_chip169
# SN5_roads_test_public_AOI_8_Mumbai_chip81
# SN5_roads_test_public_AOI_8_Mumbai_chip123SN5_roads_test_public_AOI_8_Mumbai_chip135
#
# SN5_roads_test_public_AOI_8_Mumbai_chip131
# SN5_roads_test_public_AOI_7_Moscow_chip84
# SN5_roads_test_public_AOI_8_Mumbai_chip69
# SN5_roads_test_public_AOI_8_Mumbai_chip149
# SN5_roads_test_public_AOI_7_Moscow_chip58
# SN5_roads_test_public_AOI_8_Mumbai_chip78SN5_roads_test_public_AOI_8_Mumbai_chip21SN5_roads_test_public_AOI_8_Mumbai_chip17
#
#
# SN5_roads_test_public_AOI_8_Mumbai_chip12
# SN5_roads_test_public_AOI_8_Mumbai_chip115SN5_roads_test_public_AOI_8_Mumbai_chip7
#
# SN5_roads_test_public_AOI_8_Mumbai_chip179
# SN5_roads_test_public_AOI_8_Mumbai_chip60
# SN5_roads_test_public_AOI_8_Mumbai_chip167
# SN5_roads_test_public_AOI_8_Mumbai_chip10
# SN5_roads_test_public_AOI_7_Moscow_chip196SN5_roads_test_public_AOI_8_Mumbai_chip91SN5_roads_test_public_AOI_7_Moscow_chip25
#
#
# SN5_roads_test_public_AOI_8_Mumbai_chip84SN5_roads_test_public_AOI_8_Mumbai_chip53
#
# SN5_roads_test_public_AOI_8_Mumbai_chip14
# SN5_roads_test_public_AOI_8_Mumbai_chip102
# SN5_roads_test_public_AOI_8_Mumbai_chip166SN5_roads_test_public_AOI_8_Mumbai_chip107
#
# SN5_roads_test_public_AOI_8_Mumbai_chip170
# SN5_roads_test_public_AOI_8_Mumbai_chip94SN5_roads_test_public_AOI_8_Mumbai_chip129
# SN5_roads_test_public_AOI_8_Mumbai_chip47
#
# SN5_roads_test_public_AOI_8_Mumbai_chip35
# SN5_roads_test_public_AOI_8_Mumbai_chip178
# SN5_roads_test_public_AOI_8_Mumbai_chip86
# SN5_roads_test_public_AOI_8_Mumbai_chip75
# SN5_roads_test_public_AOI_8_Mumbai_chip96
# SN5_roads_test_public_AOI_8_Mumbai_chip136SN5_roads_test_public_AOI_8_Mumbai_chip120
# SN5_roads_test_public_AOI_8_Mumbai_chip51
#
# SN5_roads_test_public_AOI_8_Mumbai_chip152SN5_roads_test_public_AOI_8_Mumbai_chip46
#
# SN5_roads_test_public_AOI_8_Mumbai_chip103
# SN5_roads_test_public_AOI_8_Mumbai_chip30
# SN5_roads_test_public_AOI_8_Mumbai_chip66SN5_roads_test_public_AOI_8_Mumbai_chip158
# SN5_roads_test_public_AOI_8_Mumbai_chip64
# SN5_roads_test_public_AOI_8_Mumbai_chip89
#
# SN5_roads_test_public_AOI_8_Mumbai_chip140
# SN5_roads_test_public_AOI_8_Mumbai_chip52
# SN5_roads_test_public_AOI_8_Mumbai_chip62SN5_roads_test_public_AOI_8_Mumbai_chip90SN5_roads_test_public_AOI_8_Mumbai_chip142
#
#
# SN5_roads_test_public_AOI_8_Mumbai_chip168
# SN5_roads_test_public_AOI_8_Mumbai_chip156SN5_roads_test_public_AOI_8_Mumbai_chip43
#
# SN5_roads_test_public_AOI_8_Mumbai_chip45
# SN5_roads_test_public_AOI_8_Mumbai_chip177
# SN5_roads_test_public_AOI_8_Mumbai_chip25
# SN5_roads_test_public_AOI_8_Mumbai_chip143
# SN5_roads_test_public_AOI_8_Mumbai_chip83SN5_roads_test_public_AOI_8_Mumbai_chip61
#
# SN5_roads_test_public_AOI_8_Mumbai_chip23
# SN5_roads_test_public_AOI_8_Mumbai_chip112SN5_roads_test_public_AOI_8_Mumbai_chip19
#
# SN5_roads_test_public_AOI_8_Mumbai_chip40
# SN5_roads_test_public_AOI_8_Mumbai_chip162SN5_roads_test_public_AOI_8_Mumbai_chip63
#
# SN5_roads_test_public_AOI_8_Mumbai_chip144SN5_roads_test_public_AOI_8_Mumbai_chip8
#
# SN5_roads_test_public_AOI_8_Mumbai_chip137SN5_roads_test_public_AOI_8_Mumbai_chip3
#
# SN5_roads_test_public_AOI_8_Mumbai_chip126
# SN5_roads_test_public_AOI_8_Mumbai_chip172
# SN5_roads_test_public_AOI_8_Mumbai_chip122
# SN5_roads_test_public_AOI_8_Mumbai_chip72
# SN5_roads_test_public_AOI_8_Mumbai_chip65
# SN5_roads_test_public_AOI_8_Mumbai_chip138SN5_roads_test_public_AOI_8_Mumbai_chip82
#
# SN5_roads_test_public_AOI_8_Mumbai_chip77
# SN5_roads_test_public_AOI_8_Mumbai_chip41
# SN5_roads_test_public_AOI_8_Mumbai_chip58SN5_roads_test_public_AOI_8_Mumbai_chip106
#
# SN5_roads_test_public_AOI_8_Mumbai_chip24
# SN5_roads_test_public_AOI_8_Mumbai_chip105
# SN5_roads_test_public_AOI_8_Mumbai_chip59SN5_roads_test_public_AOI_8_Mumbai_chip54
#
# SN5_roads_test_public_AOI_8_Mumbai_chip154SN5_roads_test_public_AOI_8_Mumbai_chip49
#
# SN5_roads_test_public_AOI_8_Mumbai_chip163
# SN5_roads_test_public_AOI_8_Mumbai_chip26
# SN5_roads_test_public_AOI_8_Mumbai_chip42
# SN5_roads_test_public_AOI_8_Mumbai_chip20
# SN5_roads_test_public_AOI_8_Mumbai_chip181
# SN5_roads_test_public_AOI_8_Mumbai_chip111
# SN5_roads_test_public_AOI_8_Mumbai_chip2
# SN5_roads_test_public_AOI_8_Mumbai_chip157SN5_roads_test_public_AOI_8_Mumbai_chip153
# SN5_roads_test_public_AOI_8_Mumbai_chip130
#
# SN5_roads_test_public_AOI_8_Mumbai_chip176
# SN5_roads_test_public_AOI_8_Mumbai_chip180
# SN5_roads_test_public_AOI_8_Mumbai_chip101
# SN5_roads_test_public_AOI_8_Mumbai_chip6
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-31:
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/users/PCON0003/osu10670/.conda/envs/pytorch-test/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
res_rows = []
# for i in range(len(results)):
#     res_rows.extend(results[i])

for i in range(len(all_files)):
    res_rows.append(process_file(all_files[i]))
# Out:
# SN5_roads_test_public_AOI_7_Moscow_chip101
# SN5_roads_test_public_AOI_7_Moscow_chip177
# SN5_roads_test_public_AOI_7_Moscow_chip134
# SN5_roads_test_public_AOI_7_Moscow_chip171
# SN5_roads_test_public_AOI_7_Moscow_chip87
# SN5_roads_test_public_AOI_7_Moscow_chip127
# SN5_roads_test_public_AOI_7_Moscow_chip120
# SN5_roads_test_public_AOI_7_Moscow_chip11
# SN5_roads_test_public_AOI_7_Moscow_chip98
# SN5_roads_test_public_AOI_7_Moscow_chip65
# SN5_roads_test_public_AOI_7_Moscow_chip14
# SN5_roads_test_public_AOI_7_Moscow_chip168
# SN5_roads_test_public_AOI_7_Moscow_chip164
# SN5_roads_test_public_AOI_7_Moscow_chip15
# SN5_roads_test_public_AOI_7_Moscow_chip56
# SN5_roads_test_public_AOI_7_Moscow_chip138
# SN5_roads_test_public_AOI_7_Moscow_chip136
# SN5_roads_test_public_AOI_7_Moscow_chip57
# SN5_roads_test_public_AOI_7_Moscow_chip178
# SN5_roads_test_public_AOI_7_Moscow_chip210
# SN5_roads_test_public_AOI_7_Moscow_chip83
# SN5_roads_test_public_AOI_7_Moscow_chip152
# SN5_roads_test_public_AOI_7_Moscow_chip223
# SN5_roads_test_public_AOI_7_Moscow_chip146
# SN5_roads_test_public_AOI_7_Moscow_chip96
# SN5_roads_test_public_AOI_7_Moscow_chip212
# SN5_roads_test_public_AOI_7_Moscow_chip79
# SN5_roads_test_public_AOI_7_Moscow_chip193
# SN5_roads_test_public_AOI_7_Moscow_chip32
# SN5_roads_test_public_AOI_7_Moscow_chip19
# SN5_roads_test_public_AOI_7_Moscow_chip155
# SN5_roads_test_public_AOI_7_Moscow_chip105
# SN5_roads_test_public_AOI_7_Moscow_chip51
# SN5_roads_test_public_AOI_7_Moscow_chip50
# SN5_roads_test_public_AOI_7_Moscow_chip52
# SN5_roads_test_public_AOI_7_Moscow_chip226
# SN5_roads_test_public_AOI_7_Moscow_chip194
# SN5_roads_test_public_AOI_7_Moscow_chip97
# SN5_roads_test_public_AOI_7_Moscow_chip54
# SN5_roads_test_public_AOI_7_Moscow_chip221
# SN5_roads_test_public_AOI_7_Moscow_chip172
# SN5_roads_test_public_AOI_7_Moscow_chip148
# SN5_roads_test_public_AOI_7_Moscow_chip132
# SN5_roads_test_public_AOI_7_Moscow_chip74
# SN5_roads_test_public_AOI_7_Moscow_chip104
# SN5_roads_test_public_AOI_7_Moscow_chip48
# SN5_roads_test_public_AOI_7_Moscow_chip62
# SN5_roads_test_public_AOI_7_Moscow_chip147
# SN5_roads_test_public_AOI_7_Moscow_chip115
# SN5_roads_test_public_AOI_7_Moscow_chip106
# SN5_roads_test_public_AOI_7_Moscow_chip208
# SN5_roads_test_public_AOI_7_Moscow_chip205
# SN5_roads_test_public_AOI_7_Moscow_chip222
# SN5_roads_test_public_AOI_7_Moscow_chip66
# SN5_roads_test_public_AOI_7_Moscow_chip197
# SN5_roads_test_public_AOI_7_Moscow_chip110
# SN5_roads_test_public_AOI_7_Moscow_chip2
# SN5_roads_test_public_AOI_7_Moscow_chip0
# SN5_roads_test_public_AOI_7_Moscow_chip100
# SN5_roads_test_public_AOI_7_Moscow_chip5
# SN5_roads_test_public_AOI_7_Moscow_chip185
# SN5_roads_test_public_AOI_7_Moscow_chip24
# SN5_roads_test_public_AOI_7_Moscow_chip161
# SN5_roads_test_public_AOI_7_Moscow_chip81
# SN5_roads_test_public_AOI_7_Moscow_chip125
# SN5_roads_test_public_AOI_7_Moscow_chip89
# SN5_roads_test_public_AOI_7_Moscow_chip95
# SN5_roads_test_public_AOI_7_Moscow_chip78
# SN5_roads_test_public_AOI_7_Moscow_chip33
# SN5_roads_test_public_AOI_7_Moscow_chip137
# SN5_roads_test_public_AOI_7_Moscow_chip85
# SN5_roads_test_public_AOI_7_Moscow_chip157
# SN5_roads_test_public_AOI_7_Moscow_chip202
# SN5_roads_test_public_AOI_7_Moscow_chip92
# SN5_roads_test_public_AOI_7_Moscow_chip166
# SN5_roads_test_public_AOI_7_Moscow_chip75
# SN5_roads_test_public_AOI_7_Moscow_chip198
# SN5_roads_test_public_AOI_7_Moscow_chip160
# SN5_roads_test_public_AOI_7_Moscow_chip174
# SN5_roads_test_public_AOI_7_Moscow_chip192
# SN5_roads_test_public_AOI_7_Moscow_chip72
# SN5_roads_test_public_AOI_7_Moscow_chip140
# SN5_roads_test_public_AOI_7_Moscow_chip189
# SN5_roads_test_public_AOI_7_Moscow_chip63
# SN5_roads_test_public_AOI_7_Moscow_chip219
# SN5_roads_test_public_AOI_7_Moscow_chip176
# SN5_roads_test_public_AOI_7_Moscow_chip10
# SN5_roads_test_public_AOI_7_Moscow_chip199
# SN5_roads_test_public_AOI_7_Moscow_chip4
# SN5_roads_test_public_AOI_7_Moscow_chip102
# SN5_roads_test_public_AOI_7_Moscow_chip201
# SN5_roads_test_public_AOI_7_Moscow_chip173
# SN5_roads_test_public_AOI_7_Moscow_chip128
# SN5_roads_test_public_AOI_7_Moscow_chip225
# SN5_roads_test_public_AOI_7_Moscow_chip190
# SN5_roads_test_public_AOI_7_Moscow_chip151
# SN5_roads_test_public_AOI_7_Moscow_chip209
# SN5_roads_test_public_AOI_7_Moscow_chip135
# SN5_roads_test_public_AOI_7_Moscow_chip67
# SN5_roads_test_public_AOI_7_Moscow_chip159
# SN5_roads_test_public_AOI_7_Moscow_chip103
# SN5_roads_test_public_AOI_7_Moscow_chip69
# SN5_roads_test_public_AOI_7_Moscow_chip200
# SN5_roads_test_public_AOI_7_Moscow_chip133
# SN5_roads_test_public_AOI_7_Moscow_chip126
# SN5_roads_test_public_AOI_7_Moscow_chip121
# SN5_roads_test_public_AOI_7_Moscow_chip204
# SN5_roads_test_public_AOI_7_Moscow_chip163
# SN5_roads_test_public_AOI_7_Moscow_chip88
# SN5_roads_test_public_AOI_7_Moscow_chip53
# SN5_roads_test_public_AOI_7_Moscow_chip179
# SN5_roads_test_public_AOI_7_Moscow_chip86
# SN5_roads_test_public_AOI_7_Moscow_chip112
# SN5_roads_test_public_AOI_7_Moscow_chip158
# SN5_roads_test_public_AOI_7_Moscow_chip130
# SN5_roads_test_public_AOI_7_Moscow_chip182
# SN5_roads_test_public_AOI_7_Moscow_chip77
# SN5_roads_test_public_AOI_7_Moscow_chip7
# SN5_roads_test_public_AOI_7_Moscow_chip8
# SN5_roads_test_public_AOI_7_Moscow_chip122
# SN5_roads_test_public_AOI_7_Moscow_chip124
# SN5_roads_test_public_AOI_7_Moscow_chip144
# SN5_roads_test_public_AOI_7_Moscow_chip61
# SN5_roads_test_public_AOI_7_Moscow_chip42
# SN5_roads_test_public_AOI_7_Moscow_chip153
# SN5_roads_test_public_AOI_7_Moscow_chip13
# SN5_roads_test_public_AOI_7_Moscow_chip6
# SN5_roads_test_public_AOI_7_Moscow_chip90
# SN5_roads_test_public_AOI_7_Moscow_chip16
# SN5_roads_test_public_AOI_7_Moscow_chip39
# SN5_roads_test_public_AOI_7_Moscow_chip38
# SN5_roads_test_public_AOI_7_Moscow_chip220
# SN5_roads_test_public_AOI_7_Moscow_chip40
# SN5_roads_test_public_AOI_7_Moscow_chip213
# SN5_roads_test_public_AOI_7_Moscow_chip119
# SN5_roads_test_public_AOI_7_Moscow_chip131
# SN5_roads_test_public_AOI_7_Moscow_chip22
# SN5_roads_test_public_AOI_7_Moscow_chip55
# SN5_roads_test_public_AOI_7_Moscow_chip27
# SN5_roads_test_public_AOI_7_Moscow_chip1
# SN5_roads_test_public_AOI_7_Moscow_chip99
# SN5_roads_test_public_AOI_7_Moscow_chip227
# SN5_roads_test_public_AOI_7_Moscow_chip71
# SN5_roads_test_public_AOI_7_Moscow_chip195
# SN5_roads_test_public_AOI_7_Moscow_chip18
# SN5_roads_test_public_AOI_7_Moscow_chip207
# SN5_roads_test_public_AOI_7_Moscow_chip175
# SN5_roads_test_public_AOI_7_Moscow_chip216
# SN5_roads_test_public_AOI_7_Moscow_chip215
# SN5_roads_test_public_AOI_7_Moscow_chip114
# SN5_roads_test_public_AOI_7_Moscow_chip187
# SN5_roads_test_public_AOI_7_Moscow_chip181
# SN5_roads_test_public_AOI_7_Moscow_chip12
# SN5_roads_test_public_AOI_7_Moscow_chip64
# SN5_roads_test_public_AOI_7_Moscow_chip129
# SN5_roads_test_public_AOI_7_Moscow_chip113
# SN5_roads_test_public_AOI_7_Moscow_chip149
# SN5_roads_test_public_AOI_7_Moscow_chip143
# SN5_roads_test_public_AOI_7_Moscow_chip35
# SN5_roads_test_public_AOI_7_Moscow_chip29
# SN5_roads_test_public_AOI_7_Moscow_chip191
# SN5_roads_test_public_AOI_7_Moscow_chip31
# SN5_roads_test_public_AOI_7_Moscow_chip186
# SN5_roads_test_public_AOI_7_Moscow_chip217
# SN5_roads_test_public_AOI_7_Moscow_chip47
# SN5_roads_test_public_AOI_7_Moscow_chip9
# SN5_roads_test_public_AOI_7_Moscow_chip26
# SN5_roads_test_public_AOI_7_Moscow_chip70
# SN5_roads_test_public_AOI_7_Moscow_chip59
# SN5_roads_test_public_AOI_7_Moscow_chip17
# SN5_roads_test_public_AOI_7_Moscow_chip93
# SN5_roads_test_public_AOI_7_Moscow_chip80
# SN5_roads_test_public_AOI_7_Moscow_chip49
# SN5_roads_test_public_AOI_7_Moscow_chip141
# SN5_roads_test_public_AOI_7_Moscow_chip30
# SN5_roads_test_public_AOI_7_Moscow_chip183
# SN5_roads_test_public_AOI_7_Moscow_chip108
# SN5_roads_test_public_AOI_7_Moscow_chip188
# SN5_roads_test_public_AOI_7_Moscow_chip44
# SN5_roads_test_public_AOI_7_Moscow_chip154
# SN5_roads_test_public_AOI_7_Moscow_chip109
# SN5_roads_test_public_AOI_7_Moscow_chip150
# SN5_roads_test_public_AOI_7_Moscow_chip46
# SN5_roads_test_public_AOI_7_Moscow_chip68
# SN5_roads_test_public_AOI_7_Moscow_chip76
# SN5_roads_test_public_AOI_7_Moscow_chip116
# SN5_roads_test_public_AOI_7_Moscow_chip214
# SN5_roads_test_public_AOI_7_Moscow_chip34
# SN5_roads_test_public_AOI_7_Moscow_chip184
# SN5_roads_test_public_AOI_7_Moscow_chip82
# SN5_roads_test_public_AOI_7_Moscow_chip117
# SN5_roads_test_public_AOI_7_Moscow_chip180
# SN5_roads_test_public_AOI_7_Moscow_chip91
# SN5_roads_test_public_AOI_7_Moscow_chip218
# SN5_roads_test_public_AOI_7_Moscow_chip196
# SN5_roads_test_public_AOI_7_Moscow_chip41
# SN5_roads_test_public_AOI_7_Moscow_chip123
# SN5_roads_test_public_AOI_7_Moscow_chip118
# SN5_roads_test_public_AOI_7_Moscow_chip43
# SN5_roads_test_public_AOI_7_Moscow_chip3
# SN5_roads_test_public_AOI_7_Moscow_chip165
# SN5_roads_test_public_AOI_7_Moscow_chip94
# SN5_roads_test_public_AOI_7_Moscow_chip36
# SN5_roads_test_public_AOI_7_Moscow_chip58
# SN5_roads_test_public_AOI_7_Moscow_chip45
# SN5_roads_test_public_AOI_7_Moscow_chip60
# SN5_roads_test_public_AOI_7_Moscow_chip84
# SN5_roads_test_public_AOI_7_Moscow_chip23
# SN5_roads_test_public_AOI_7_Moscow_chip21
# SN5_roads_test_public_AOI_7_Moscow_chip37
# SN5_roads_test_public_AOI_7_Moscow_chip170
# SN5_roads_test_public_AOI_7_Moscow_chip20
# SN5_roads_test_public_AOI_7_Moscow_chip142
# SN5_roads_test_public_AOI_7_Moscow_chip139
# SN5_roads_test_public_AOI_7_Moscow_chip111
# SN5_roads_test_public_AOI_7_Moscow_chip156
# SN5_roads_test_public_AOI_7_Moscow_chip73
# SN5_roads_test_public_AOI_7_Moscow_chip211
# SN5_roads_test_public_AOI_7_Moscow_chip25
# SN5_roads_test_public_AOI_7_Moscow_chip206
# SN5_roads_test_public_AOI_7_Moscow_chip224
# SN5_roads_test_public_AOI_7_Moscow_chip145
# SN5_roads_test_public_AOI_7_Moscow_chip162
# SN5_roads_test_public_AOI_7_Moscow_chip167
# SN5_roads_test_public_AOI_7_Moscow_chip169
# SN5_roads_test_public_AOI_7_Moscow_chip203
# SN5_roads_test_public_AOI_7_Moscow_chip28
# SN5_roads_test_public_AOI_7_Moscow_chip107
# SN5_roads_test_public_AOI_8_Mumbai_chip80
# SN5_roads_test_public_AOI_8_Mumbai_chip36
# SN5_roads_test_public_AOI_8_Mumbai_chip165
# SN5_roads_test_public_AOI_8_Mumbai_chip132
# SN5_roads_test_public_AOI_8_Mumbai_chip125
# SN5_roads_test_public_AOI_8_Mumbai_chip127
# SN5_roads_test_public_AOI_8_Mumbai_chip109
# SN5_roads_test_public_AOI_8_Mumbai_chip71
# SN5_roads_test_public_AOI_8_Mumbai_chip146
# SN5_roads_test_public_AOI_8_Mumbai_chip37
# SN5_roads_test_public_AOI_8_Mumbai_chip11
# SN5_roads_test_public_AOI_8_Mumbai_chip85
# SN5_roads_test_public_AOI_8_Mumbai_chip44
# SN5_roads_test_public_AOI_8_Mumbai_chip31
# SN5_roads_test_public_AOI_8_Mumbai_chip13
# SN5_roads_test_public_AOI_8_Mumbai_chip5
# SN5_roads_test_public_AOI_8_Mumbai_chip79
# SN5_roads_test_public_AOI_8_Mumbai_chip53
# SN5_roads_test_public_AOI_8_Mumbai_chip108
# SN5_roads_test_public_AOI_8_Mumbai_chip147
# SN5_roads_test_public_AOI_8_Mumbai_chip149
# SN5_roads_test_public_AOI_8_Mumbai_chip97
# SN5_roads_test_public_AOI_8_Mumbai_chip22
# SN5_roads_test_public_AOI_8_Mumbai_chip57
# SN5_roads_test_public_AOI_8_Mumbai_chip128
# SN5_roads_test_public_AOI_8_Mumbai_chip148
# SN5_roads_test_public_AOI_8_Mumbai_chip145
# SN5_roads_test_public_AOI_8_Mumbai_chip74
# SN5_roads_test_public_AOI_8_Mumbai_chip141
# SN5_roads_test_public_AOI_8_Mumbai_chip21
# SN5_roads_test_public_AOI_8_Mumbai_chip118
# SN5_roads_test_public_AOI_8_Mumbai_chip88
# SN5_roads_test_public_AOI_8_Mumbai_chip78
# SN5_roads_test_public_AOI_8_Mumbai_chip134
# SN5_roads_test_public_AOI_8_Mumbai_chip164
# SN5_roads_test_public_AOI_8_Mumbai_chip81
# SN5_roads_test_public_AOI_8_Mumbai_chip98
# SN5_roads_test_public_AOI_8_Mumbai_chip95
# SN5_roads_test_public_AOI_8_Mumbai_chip113
# SN5_roads_test_public_AOI_8_Mumbai_chip1
# SN5_roads_test_public_AOI_8_Mumbai_chip131
# SN5_roads_test_public_AOI_8_Mumbai_chip103
# SN5_roads_test_public_AOI_8_Mumbai_chip124
# SN5_roads_test_public_AOI_8_Mumbai_chip169
# SN5_roads_test_public_AOI_8_Mumbai_chip117
# SN5_roads_test_public_AOI_8_Mumbai_chip175
# SN5_roads_test_public_AOI_8_Mumbai_chip171
# SN5_roads_test_public_AOI_8_Mumbai_chip60
# SN5_roads_test_public_AOI_8_Mumbai_chip67
# SN5_roads_test_public_AOI_8_Mumbai_chip68
# SN5_roads_test_public_AOI_8_Mumbai_chip50
# SN5_roads_test_public_AOI_8_Mumbai_chip99
# SN5_roads_test_public_AOI_8_Mumbai_chip173
# SN5_roads_test_public_AOI_8_Mumbai_chip123
# SN5_roads_test_public_AOI_8_Mumbai_chip92
# SN5_roads_test_public_AOI_8_Mumbai_chip102
# SN5_roads_test_public_AOI_8_Mumbai_chip152
# SN5_roads_test_public_AOI_8_Mumbai_chip150
# SN5_roads_test_public_AOI_8_Mumbai_chip110
# SN5_roads_test_public_AOI_8_Mumbai_chip75
# SN5_roads_test_public_AOI_8_Mumbai_chip116
# SN5_roads_test_public_AOI_8_Mumbai_chip135
# SN5_roads_test_public_AOI_8_Mumbai_chip10
# SN5_roads_test_public_AOI_8_Mumbai_chip15
# SN5_roads_test_public_AOI_8_Mumbai_chip166
# SN5_roads_test_public_AOI_8_Mumbai_chip143
# SN5_roads_test_public_AOI_8_Mumbai_chip159
# SN5_roads_test_public_AOI_8_Mumbai_chip89
# SN5_roads_test_public_AOI_8_Mumbai_chip144
# SN5_roads_test_public_AOI_8_Mumbai_chip114
# SN5_roads_test_public_AOI_8_Mumbai_chip46
# SN5_roads_test_public_AOI_8_Mumbai_chip8
# SN5_roads_test_public_AOI_8_Mumbai_chip161
# SN5_roads_test_public_AOI_8_Mumbai_chip167
# SN5_roads_test_public_AOI_8_Mumbai_chip61
# SN5_roads_test_public_AOI_8_Mumbai_chip48
# SN5_roads_test_public_AOI_8_Mumbai_chip120
# SN5_roads_test_public_AOI_8_Mumbai_chip20
# SN5_roads_test_public_AOI_8_Mumbai_chip55
# SN5_roads_test_public_AOI_8_Mumbai_chip107
# SN5_roads_test_public_AOI_8_Mumbai_chip138
# SN5_roads_test_public_AOI_8_Mumbai_chip104
# SN5_roads_test_public_AOI_8_Mumbai_chip47
# SN5_roads_test_public_AOI_8_Mumbai_chip122
# SN5_roads_test_public_AOI_8_Mumbai_chip87
# SN5_roads_test_public_AOI_8_Mumbai_chip91
# SN5_roads_test_public_AOI_8_Mumbai_chip172
# SN5_roads_test_public_AOI_8_Mumbai_chip39
# SN5_roads_test_public_AOI_8_Mumbai_chip69
# SN5_roads_test_public_AOI_8_Mumbai_chip84
# SN5_roads_test_public_AOI_8_Mumbai_chip4
# SN5_roads_test_public_AOI_8_Mumbai_chip51
# SN5_roads_test_public_AOI_8_Mumbai_chip105
# SN5_roads_test_public_AOI_8_Mumbai_chip17
# SN5_roads_test_public_AOI_8_Mumbai_chip43
# SN5_roads_test_public_AOI_8_Mumbai_chip83
# SN5_roads_test_public_AOI_8_Mumbai_chip12
# SN5_roads_test_public_AOI_8_Mumbai_chip3
# SN5_roads_test_public_AOI_8_Mumbai_chip26
# SN5_roads_test_public_AOI_8_Mumbai_chip115
# SN5_roads_test_public_AOI_8_Mumbai_chip19
# SN5_roads_test_public_AOI_8_Mumbai_chip24
# SN5_roads_test_public_AOI_8_Mumbai_chip7
# SN5_roads_test_public_AOI_8_Mumbai_chip64
# SN5_roads_test_public_AOI_8_Mumbai_chip45
# SN5_roads_test_public_AOI_8_Mumbai_chip179
# SN5_roads_test_public_AOI_8_Mumbai_chip86
# SN5_roads_test_public_AOI_8_Mumbai_chip112
# SN5_roads_test_public_AOI_8_Mumbai_chip14
# SN5_roads_test_public_AOI_8_Mumbai_chip41
# SN5_roads_test_public_AOI_8_Mumbai_chip2
# SN5_roads_test_public_AOI_8_Mumbai_chip170
# SN5_roads_test_public_AOI_8_Mumbai_chip82
# SN5_roads_test_public_AOI_8_Mumbai_chip153
# SN5_roads_test_public_AOI_8_Mumbai_chip129
# SN5_roads_test_public_AOI_8_Mumbai_chip106
# SN5_roads_test_public_AOI_8_Mumbai_chip6
# SN5_roads_test_public_AOI_8_Mumbai_chip94
# SN5_roads_test_public_AOI_8_Mumbai_chip66
# SN5_roads_test_public_AOI_8_Mumbai_chip25
# SN5_roads_test_public_AOI_8_Mumbai_chip178
# SN5_roads_test_public_AOI_8_Mumbai_chip162
# SN5_roads_test_public_AOI_8_Mumbai_chip157
# SN5_roads_test_public_AOI_8_Mumbai_chip35
# SN5_roads_test_public_AOI_8_Mumbai_chip72
# SN5_roads_test_public_AOI_8_Mumbai_chip176
# SN5_roads_test_public_AOI_8_Mumbai_chip96
# SN5_roads_test_public_AOI_8_Mumbai_chip40
# SN5_roads_test_public_AOI_8_Mumbai_chip42
# SN5_roads_test_public_AOI_8_Mumbai_chip136
# SN5_roads_test_public_AOI_8_Mumbai_chip52
# SN5_roads_test_public_AOI_8_Mumbai_chip137
# SN5_roads_test_public_AOI_8_Mumbai_chip30
# SN5_roads_test_public_AOI_8_Mumbai_chip49
# SN5_roads_test_public_AOI_8_Mumbai_chip111
# SN5_roads_test_public_AOI_8_Mumbai_chip158
# SN5_roads_test_public_AOI_8_Mumbai_chip65
# SN5_roads_test_public_AOI_8_Mumbai_chip130
# SN5_roads_test_public_AOI_8_Mumbai_chip140
# SN5_roads_test_public_AOI_8_Mumbai_chip126
# SN5_roads_test_public_AOI_8_Mumbai_chip77
# SN5_roads_test_public_AOI_8_Mumbai_chip62
# SN5_roads_test_public_AOI_8_Mumbai_chip23
# SN5_roads_test_public_AOI_8_Mumbai_chip63
# SN5_roads_test_public_AOI_8_Mumbai_chip90
# SN5_roads_test_public_AOI_8_Mumbai_chip154
# SN5_roads_test_public_AOI_8_Mumbai_chip180
# SN5_roads_test_public_AOI_8_Mumbai_chip142
# SN5_roads_test_public_AOI_8_Mumbai_chip59
# SN5_roads_test_public_AOI_8_Mumbai_chip101
# SN5_roads_test_public_AOI_8_Mumbai_chip168
# SN5_roads_test_public_AOI_8_Mumbai_chip54
# SN5_roads_test_public_AOI_8_Mumbai_chip181
# SN5_roads_test_public_AOI_8_Mumbai_chip156
# SN5_roads_test_public_AOI_8_Mumbai_chip58
# SN5_roads_test_public_AOI_8_Mumbai_chip163
# SN5_roads_test_public_AOI_8_Mumbai_chip177
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     try:
# --> 564         columns = _validate_or_indexify_columns(content, columns)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     688             raise AssertionError(
# --> 689                 f"{len(columns)} columns passed, passed data had "
#     690                 f"{len(content)} columns"
#
# AssertionError: 4 columns passed, passed data had 71 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-fea147fbcb85> in <module>
#       6     res_rows.append(process_file(all_files[i]))
#       7
# ----> 8 sub = pd.DataFrame(res_rows, columns=['ImageId', 'WKT_Pix', 'length_m', 'travel_time_s'])
#       9 sub.to_csv(path.join('./wdata', out_file), index=False, header=False)
#      10
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                     if is_named_tuple(data[0]) and columns is None:
#     508                         columns = data[0]._fields
# --> 509                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     510                     columns = ensure_index(columns)
#     511
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     522         return [], []  # columns if columns is not None else []
#     523     if isinstance(data[0], (list, tuple)):
# --> 524         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     525     elif isinstance(data[0], abc.Mapping):
#     526         return _list_of_dict_to_arrays(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     566     except AssertionError as e:
# --> 567         raise ValueError(e) from e
#     568     return result, columns
#     569
#
# ValueError: 4 columns passed, passed data had 71 columns

# %%
row_test = []
for i in res_rows:
    row_test.extend(i)

# %%
res_rows = row_test

# %%
out_file
# Out:
# './wdata/solution.csv'

# %%
sub = pd.DataFrame(res_rows, columns=['ImageId', 'WKT_Pix', 'length_m', 'travel_time_s'])
sub.to_csv(path.join('./wdata', out_file), index=False, header=False)

elapsed = timeit.default_timer() - t0
print('Submission file created! Time: {:.3f} min'.format(elapsed / 60))
# Out:
# Submission file created! Time: 0.081 min

# %%
sub
# Out:
#                                          ImageId  \
# 0     SN5_roads_test_public_AOI_7_Moscow_chip101
# 1     SN5_roads_test_public_AOI_7_Moscow_chip101
# 2     SN5_roads_test_public_AOI_7_Moscow_chip177
# 3     SN5_roads_test_public_AOI_7_Moscow_chip177
# 4     SN5_roads_test_public_AOI_7_Moscow_chip177
# ...                                          ...
# 9487  SN5_roads_test_public_AOI_8_Mumbai_chip177
# 9488  SN5_roads_test_public_AOI_8_Mumbai_chip177
# 9489  SN5_roads_test_public_AOI_8_Mumbai_chip177
# 9490  SN5_roads_test_public_AOI_8_Mumbai_chip177
# 9491  SN5_roads_test_public_AOI_8_Mumbai_chip177
#
#                                                 WKT_Pix    length_m  \
# 0     LINESTRING (32 130, 33 136, 42 176, 66 254, 70...  343.038923
# 1     LINESTRING (293 1109, 318 1212, 332 1259, 334 ...   54.622219
# 2     LINESTRING (589 0, 574 7, 515 105, 488 143, 46...   66.813805
# 3     LINESTRING (461 177, 413 176, 373 178, 343 183...   32.065023
# 4     LINESTRING (461 177, 468 182, 591 217, 633 227...   72.694431
# ...                                                 ...         ...
# 9487             LINESTRING (645 661, 770 670, 776 670)   38.858847
# 9488          LINESTRING (0 873, 0 908, 0 1011, 0 1055)   56.633023
# 9489                        LINESTRING (0 1055, 0 1131)   23.648954
# 9490  LINESTRING (949 1192, 926 1267, 925 1290, 924 ...   34.288491
# 9491          LINESTRING (694 1295, 713 1299, 742 1299)   14.335870
#
#       travel_time_s
# 0            27.517
# 1             5.405
# 2             9.184
# 3             4.174
# 4             9.695
# ...             ...
# 9487          2.855
# 9488          4.452
# 9489          1.906
# 9490          1.724
# 9491          1.133
#
# [9492 rows x 4 columns]

# %%
pred_folder = './wdata/test_pred'
msk0 = cv2.imread(path.join(pred_folder, img_id + '_speed0.png'), cv2.IMREAD_UNCHANGED)
msk1 = cv2.imread(path.join(pred_folder, img_id + '_speed1.png'), cv2.IMREAD_UNCHANGED)
msk2 = cv2.imread(path.join(pred_folder, img_id + '_speed2.png'), cv2.IMREAD_UNCHANGED)
msk = np.concatenate((msk0, msk1, msk2), axis=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-bb829782ca03> in <module>
#       3 msk1 = cv2.imread(path.join(pred_folder, img_id + '_speed1.png'), cv2.IMREAD_UNCHANGED)
#       4 msk2 = cv2.imread(path.join(pred_folder, img_id + '_speed2.png'), cv2.IMREAD_UNCHANGED)
# ----> 5 msk = np.concatenate((msk0, msk1, msk2), axis=2)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
msk0

# %%
path.join(pred_folder, img_id + '_speed0.png')
# Out:
# './wdata/test_pred/SN5_roads_test_public_AOI_7_Moscow_PS-MS_chip193_speed0.png'

# %%
SN5_roads_test_public_AOI_7_Moscow_chip193_speed0.png
